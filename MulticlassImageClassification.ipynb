# %% [markdown]
# <a href="https://colab.research.google.com/github/huzefa62/Data-Science-Portfolio/blob/master/MulticlassImageClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from torchvision import datasets
import torchvision.transforms as transforms
import os

# %%
path2data="./data"
if not os.path.exists(path2data):
    os.mkdir(path2data)
    
data_transformer = transforms.Compose([transforms.ToTensor()])
train_ds=datasets.STL10(path2data, split='train', 
                        download=True,transform=data_transformer)
print(train_ds.data.shape)
# Out:
# Downloading http://ai.stanford.edu/~acoates/stl10/stl10_binary.tar.gz to ./data/stl10_binary.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/stl10_binary.tar.gz to ./data
# (5000, 3, 96, 96)

# %%
# !nvidia-smi
# Out:
# Mon Sep  7 09:35:33 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.66       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8    31W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import collections

y_train=[y for _,y in train_ds]
counter_train=collections.Counter(y_train)
print(counter_train)
# Out:
# Counter({1: 500, 5: 500, 6: 500, 3: 500, 9: 500, 7: 500, 4: 500, 8: 500, 0: 500, 2: 500})

# %%
test0_ds=datasets.STL10(path2data, split='test', 
                        download=True,transform=data_transformer)
print(test0_ds.data.shape)
# Out:
# Files already downloaded and verified
# (8000, 3, 96, 96)

# %%
from sklearn.model_selection import StratifiedShuffleSplit

sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=0)

indices=list(range(len(test0_ds)))
y_test0=[y for _,y in test0_ds]
for test_index, val_index in sss.split(indices, y_test0):
    print("test:", test_index, "val:", val_index)
    print(len(val_index),len(test_index))
# Out:
# test: [2096 4321 2767 ... 3206 3910 2902] val: [6332 6852 1532 ... 5766 4469 1011]
# 1600 6400

# %%
from torch.utils.data import Subset

val_ds=Subset(test0_ds,val_index)
test_ds=Subset(test0_ds,test_index)

# %%
import collections
import numpy as np

y_test=[y for _,y in test_ds]
y_val=[y for _,y in val_ds]

counter_test=collections.Counter(y_test)
counter_val=collections.Counter(y_val)
print(counter_test)
print(counter_val)
# Out:
# Counter({6: 640, 0: 640, 4: 640, 5: 640, 9: 640, 2: 640, 3: 640, 1: 640, 7: 640, 8: 640})
# Counter({2: 160, 8: 160, 3: 160, 6: 160, 4: 160, 1: 160, 5: 160, 9: 160, 0: 160, 7: 160})

# %%
from torchvision import utils
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

np.random.seed(0)

# %%
def show(img,y=None,color=True):
    npimg = img.numpy()
    npimg_tr=np.transpose(npimg, (1,2,0))
    plt.imshow(npimg_tr)
    if y is not None:
        plt.title("label: "+str(y))

# %%
grid_size=4
rnd_inds=np.random.randint(0,len(train_ds),grid_size)
print("image indices:",rnd_inds)
# Out:
# image indices: [2732 2607 1653 3264]

# %%
x_grid=[train_ds[i][0] for i in rnd_inds]
y_grid=[train_ds[i][1] for i in rnd_inds]

x_grid=utils.make_grid(x_grid, nrow=4, padding=1)
print(x_grid.shape)
# Out:
# torch.Size([3, 98, 389])

# %%
# call helper function
plt.figure(figsize=(10,10))
show(x_grid,y_grid)

# %%
np.random.seed(0)

grid_size=4
rnd_inds=np.random.randint(0,len(val_ds),grid_size)
print("image indices:",rnd_inds)

x_grid=[val_ds[i][0] for i in rnd_inds]
y_grid=[val_ds[i][1] for i in rnd_inds]

x_grid=utils.make_grid(x_grid, nrow=4, padding=2)
print(x_grid.shape)

plt.figure(figsize=(10,10))
show(x_grid,y_grid)
# Out:
# image indices: [ 684  559 1216  835]
# torch.Size([3, 100, 394])

# %%
import numpy as np

meanRGB=[np.mean(x.numpy(),axis=(1,2)) for x,_ in train_ds]
stdRGB=[np.std(x.numpy(),axis=(1,2)) for x,_ in train_ds]

meanR=np.mean([m[0] for m in meanRGB])
meanG=np.mean([m[1] for m in meanRGB])
meanB=np.mean([m[2] for m in meanRGB])

stdR=np.mean([s[0] for s in stdRGB])
stdG=np.mean([s[1] for s in stdRGB])
stdB=np.mean([s[2] for s in stdRGB])

print(meanR,meanG,meanB)
print(stdR,stdG,stdB)
# Out:
# 0.4467106 0.43980986 0.40664646
# 0.22414584 0.22148906 0.22389975

# %%
train_transformer = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),  
    transforms.RandomVerticalFlip(p=0.5),  
    transforms.ToTensor(),
    transforms.Normalize([meanR, meanG, meanB], [stdR, stdG, stdB])])
                 

test0_transformer = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([meanR, meanG, meanB], [stdR, stdG, stdB]),
    ])

# %%
train_ds.transform=train_transformer
test0_ds.transform=test0_transformer

# %%
import torch
np.random.seed(0)
torch.manual_seed(0)

grid_size=4
rnd_inds=np.random.randint(0,len(train_ds),grid_size)
print("image indices:",rnd_inds)

x_grid=[train_ds[i][0] for i in rnd_inds]
y_grid=[train_ds[i][1] for i in rnd_inds]

x_grid=utils.make_grid(x_grid, nrow=4, padding=2)
print(x_grid.shape)

plt.figure(figsize=(10,10))
show(x_grid,y_grid)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# image indices: [2732 2607 1653 3264]
# torch.Size([3, 100, 394])

# %%
from torch.utils.data import DataLoader

train_dl = DataLoader(train_ds, batch_size=32, shuffle=True)
val_dl = DataLoader(val_ds, batch_size=64, shuffle=False)

# %%
for x, y in train_dl:
    print(x.shape)
    print(y.shape)
    break
# Out:
# torch.Size([32, 3, 96, 96])
# torch.Size([32])

# %%
# extract a batch from validation data
for x, y in val_dl:
    print(x.shape)
    print(y.shape)
    break
# Out:
# torch.Size([64, 3, 96, 96])
# torch.Size([64])

# %%
from torchvision import models
import torch

model_resnet18 = models.resnet18(pretrained=False)

# %%
print(model_resnet18)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
from torch import nn

num_classes=10
num_ftrs = model_resnet18.fc.in_features 
model_resnet18.fc = nn.Linear(num_ftrs, num_classes)

device = torch.device("cuda:0")
model_resnet18.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
from torchsummary import summary
summary(model_resnet18,input_size=(3,224,224), device=device.type)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#        BasicBlock-11           [-1, 64, 56, 56]               0
#            Conv2d-12           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-13           [-1, 64, 56, 56]             128
#              ReLU-14           [-1, 64, 56, 56]               0
#            Conv2d-15           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-16           [-1, 64, 56, 56]             128
#              ReLU-17           [-1, 64, 56, 56]               0
#        BasicBlock-18           [-1, 64, 56, 56]               0
#            Conv2d-19          [-1, 128, 28, 28]          73,728
#       BatchNorm2d-20          [-1, 128, 28, 28]             256
#              ReLU-21          [-1, 128, 28, 28]               0
#            Conv2d-22          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-23          [-1, 128, 28, 28]             256
#            Conv2d-24          [-1, 128, 28, 28]           8,192
#       BatchNorm2d-25          [-1, 128, 28, 28]             256
#              ReLU-26          [-1, 128, 28, 28]               0
#        BasicBlock-27          [-1, 128, 28, 28]               0
#            Conv2d-28          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-29          [-1, 128, 28, 28]             256
#              ReLU-30          [-1, 128, 28, 28]               0
#            Conv2d-31          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-32          [-1, 128, 28, 28]             256
#              ReLU-33          [-1, 128, 28, 28]               0
#        BasicBlock-34          [-1, 128, 28, 28]               0
#            Conv2d-35          [-1, 256, 14, 14]         294,912
#       BatchNorm2d-36          [-1, 256, 14, 14]             512
#              ReLU-37          [-1, 256, 14, 14]               0
#            Conv2d-38          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-39          [-1, 256, 14, 14]             512
#            Conv2d-40          [-1, 256, 14, 14]          32,768
#       BatchNorm2d-41          [-1, 256, 14, 14]             512
#              ReLU-42          [-1, 256, 14, 14]               0
#        BasicBlock-43          [-1, 256, 14, 14]               0
#            Conv2d-44          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-45          [-1, 256, 14, 14]             512
#              ReLU-46          [-1, 256, 14, 14]               0
#            Conv2d-47          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-48          [-1, 256, 14, 14]             512
#              ReLU-49          [-1, 256, 14, 14]               0
#        BasicBlock-50          [-1, 256, 14, 14]               0
#            Conv2d-51            [-1, 512, 7, 7]       1,179,648
#       BatchNorm2d-52            [-1, 512, 7, 7]           1,024
#              ReLU-53            [-1, 512, 7, 7]               0
#            Conv2d-54            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-55            [-1, 512, 7, 7]           1,024
#            Conv2d-56            [-1, 512, 7, 7]         131,072
#       BatchNorm2d-57            [-1, 512, 7, 7]           1,024
#              ReLU-58            [-1, 512, 7, 7]               0
#        BasicBlock-59            [-1, 512, 7, 7]               0
#            Conv2d-60            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-61            [-1, 512, 7, 7]           1,024
#              ReLU-62            [-1, 512, 7, 7]               0
#            Conv2d-63            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-64            [-1, 512, 7, 7]           1,024
#              ReLU-65            [-1, 512, 7, 7]               0
#        BasicBlock-66            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                   [-1, 10]           5,130
# ================================================================
# Total params: 11,181,642
# Trainable params: 11,181,642
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 62.79
# Params size (MB): 42.65
# Estimated Total Size (MB): 106.01
# ----------------------------------------------------------------

# %%
for w in model_resnet18.parameters():
    w=w.data.cpu()
    print(w.shape)
    break
# Out:
# torch.Size([64, 3, 7, 7])

# %%
min_w=torch.min(w)
w1 = (-1/(2*min_w))*w + 0.5 
print(torch.min(w1).item(),torch.max(w1).item())
# Out:
# 2.9802322387695312e-08 0.9347777366638184

# %%
grid_size=len(w1)
x_grid=[w1[i] for i in range(grid_size)]
x_grid=utils.make_grid(x_grid, nrow=8, padding=1)
print(x_grid.shape)

plt.figure(figsize=(10,10))
show(x_grid)
# Out:
# torch.Size([3, 65, 65])

# %%
from torchvision import models
import torch

resnet18_pretrained = models.resnet18(pretrained=True)

num_classes=10
num_ftrs = resnet18_pretrained.fc.in_features
resnet18_pretrained.fc = nn.Linear(num_ftrs, num_classes)

device = torch.device("cuda:0")
resnet18_pretrained.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
loss_func = nn.CrossEntropyLoss(reduction="sum")

# %%
torch.manual_seed(0)

n,c=4,5
y = torch.randn(n, c, requires_grad=True)
print(y.shape)

loss_func = nn.CrossEntropyLoss(reduction="sum")
target = torch.randint(c,size=(n,))
print(target.shape)

loss = loss_func(y, target)
print(loss.item())
# Out:
# torch.Size([4, 5])
# torch.Size([4])
# 7.312585353851318

# %%
loss.backward()
print (y.data)
# Out:
# tensor([[-1.1258, -1.1524, -0.2506, -0.4339,  0.5988],
#         [-1.5551, -0.3414,  1.8530,  0.4681, -0.1577],
#         [ 1.4437,  0.2660,  1.3894,  1.5863,  0.9463],
#         [-0.8437,  0.9318,  1.2590,  2.0050,  0.0537]])

# %%
from torch import optim
opt = optim.Adam(model_resnet18.parameters(), lr=1e-4)

# %%
def get_lr(opt):
    for param_group in opt.param_groups:
        return param_group['lr']

current_lr=get_lr(opt)
print('current lr={}'.format(current_lr))
# Out:
# current lr=0.0001

# %%
from torch.optim.lr_scheduler import CosineAnnealingLR

lr_scheduler = CosineAnnealingLR(opt,T_max=2,eta_min=1e-5)

# %%
for i in range(10):
    lr_scheduler.step()
    print("epoch %s, lr: %.1e" %(i,get_lr(opt)))
# Out:
# epoch 0, lr: 5.5e-05
# epoch 1, lr: 1.0e-05
# epoch 2, lr: 5.5e-05
# epoch 3, lr: 1.0e-04
# epoch 4, lr: 5.5e-05
# epoch 5, lr: 1.0e-05
# epoch 6, lr: 5.5e-05
# epoch 7, lr: 1.0e-04
# epoch 8, lr: 5.5e-05
# epoch 9, lr: 1.0e-05
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:123: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)

# %%
def metrics_batch(output, target):
    pred = output.argmax(dim=1, keepdim=True)
    
    corrects=pred.eq(target.view_as(pred)).sum().item()
    return corrects

# %%
def loss_batch(loss_func, output, target, opt=None):  
    loss = loss_func(output, target)   
    metric_b = metrics_batch(output,target)
    
    if opt is not None:
        opt.zero_grad()
        loss.backward()
        opt.step()

    return loss.item(), metric_b

# %%
def loss_epoch(model,loss_func,dataset_dl,sanity_check=False,opt=None):
    running_loss=0.0
    running_metric=0.0
    len_data=len(dataset_dl.dataset)
    for xb,yb in dataset_dl:
        xb=xb.to(device)
        yb=yb.to(device)
        output=model(xb)
        loss_b,metric_b=loss_batch(loss_func, output, yb, opt)
        running_loss+=loss_b
        if metric_b is not None:
            running_metric+=metric_b

        if sanity_check is True:
            break

        loss=running_loss/float(len_data)
        metric=running_metric/float(len_data)
        return loss, metric

# %%
def train_val(model, params):
    num_epochs=params["num_epochs"]
    loss_func=params["loss_func"]
    opt=params["optimizer"]
    train_dl=params["train_dl"]
    val_dl=params["val_dl"]
    sanity_check=params["sanity_check"]
    lr_scheduler=params["lr_scheduler"]
    path2weights=params["path2weights"]
    loss_history={
        "train": [],
        "val": [],
    }
    
    metric_history={
        "train": [],
        "val": [],
    }
     
    best_model_wts = copy.deepcopy(model.state_dict())

    best_loss=float('inf')

# %%
def train_val(model, params):
    # extract model parameters
    num_epochs=params["num_epochs"]
    loss_func=params["loss_func"]
    opt=params["optimizer"]
    train_dl=params["train_dl"]
    val_dl=params["val_dl"]
    sanity_check=params["sanity_check"]
    lr_scheduler=params["lr_scheduler"]
    path2weights=params["path2weights"]
    
    # history of loss values in each epoch
    loss_history={
        "train": [],
        "val": [],
    }
    
    # histroy of metric values in each epoch
    metric_history={
        "train": [],
        "val": [],
    }
    
    # a deep copy of weights for the best performing model
    best_model_wts = copy.deepcopy(model.state_dict())
    
    # initialize best loss to a large value
    best_loss=float('inf')
    
    # main loop
    for epoch in range(num_epochs):
        
        # get current learning rate
        current_lr=get_lr(opt)
        print('Epoch {}/{}, current lr={}'.format(epoch, num_epochs - 1, current_lr))
        
        # train model on training dataset
        model.train()
        train_loss, train_metric=loss_epoch(model,loss_func,train_dl,sanity_check,opt)

        # collect loss and metric for training dataset
        loss_history["train"].append(train_loss)
        metric_history["train"].append(train_metric)
        
        # evaluate model on validation dataset    
        model.eval()
        with torch.no_grad():
            val_loss, val_metric=loss_epoch(model,loss_func,val_dl,sanity_check)
        
       
        # store best model
        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            
            # store weights into a local file
            torch.save(model.state_dict(), path2weights)
            print("Copied best model weights!")
        
        # collect loss and metric for validation dataset
        loss_history["val"].append(val_loss)
        metric_history["val"].append(val_metric)
        
        # learning rate schedule
        lr_scheduler.step()

        print("train loss: %.6f, dev loss: %.6f, accuracy: %.2f" %(train_loss,val_loss,100*val_metric))
        print("-"*10) 

    # load best model weights
    model.load_state_dict(best_model_wts)
        
    return model, loss_history, metric_history

# %%
import copy

loss_func = nn.CrossEntropyLoss(reduction="sum")
opt = optim.Adam(model_resnet18.parameters(), lr=1e-4)
lr_scheduler = CosineAnnealingLR(opt,T_max=5,eta_min=1e-6)
os.makedirs("./models", exist_ok=True)
params_train={
 "num_epochs": 3,
 "optimizer": opt,
 "loss_func": loss_func,
 "train_dl": train_dl,
 "val_dl": val_dl,
 "sanity_check": False,
 "lr_scheduler": lr_scheduler,
 "path2weights": "./models/resnet18.pt",
}

# train and validate the model
#model_resnet18,loss_hist,metric_hist=train_val(model_resnet18,params_train)

# %%
model_resnet18,loss_hist,metric_hist=train_val(model_resnet18,params_train)
# Out:
# Epoch 0/2, current lr=0.0001
# Copied best model weights!
# train loss: 0.015577, dev loss: 0.091893, accuracy: 0.62
# ----------
# Epoch 1/2, current lr=9.05463412215599e-05
# Copied best model weights!
# train loss: 0.015255, dev loss: 0.091368, accuracy: 0.62
# ----------
# Epoch 2/2, current lr=6.57963412215599e-05
# Copied best model weights!
# train loss: 0.016079, dev loss: 0.091307, accuracy: 0.62
# ----------

# %%
# Train-Validation Progress
num_epochs=params_train["num_epochs"]

# plot loss progress
plt.title("Train-Val Loss")
plt.plot(range(1,num_epochs+1),loss_hist["train"],label="train")
plt.plot(range(1,num_epochs+1),loss_hist["val"],label="val")
plt.ylabel("Loss")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# plot accuracy progress
plt.title("Train-Val Accuracy")
plt.plot(range(1,num_epochs+1),metric_hist["train"],label="train")
plt.plot(range(1,num_epochs+1),metric_hist["val"],label="val")
plt.ylabel("Accuracy")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# %%
import copy

loss_func = nn.CrossEntropyLoss(reduction="sum")
opt = optim.Adam(resnet18_pretrained.parameters(), lr=1e-4)
lr_scheduler = CosineAnnealingLR(opt,T_max=5,eta_min=1e-6)

params_train={
 "num_epochs": 100,
 "optimizer": opt,
 "loss_func": loss_func,
 "train_dl": train_dl,
 "val_dl": val_dl,
 "sanity_check": False,
 "lr_scheduler": lr_scheduler,
 "path2weights": "./models/resnet18_pretrained.pt",
}

resnet18_pretrained,loss_hist,metric_hist=train_val(resnet18_pretrained,params_train)
# Out:
# Epoch 0/99, current lr=0.0001
# Copied best model weights!
# train loss: 0.016403, dev loss: 0.112326, accuracy: 0.69
# ----------
# Epoch 1/99, current lr=9.05463412215599e-05
# Copied best model weights!
# train loss: 0.014788, dev loss: 0.103241, accuracy: 0.75
# ----------
# Epoch 2/99, current lr=6.57963412215599e-05
# Copied best model weights!
# train loss: 0.014853, dev loss: 0.097764, accuracy: 0.75
# ----------
# Epoch 3/99, current lr=3.52036587784401e-05
# Copied best model weights!
# train loss: 0.013254, dev loss: 0.094382, accuracy: 0.88
# ----------
# Epoch 4/99, current lr=1.0453658778440105e-05
# Copied best model weights!
# train loss: 0.013934, dev loss: 0.092888, accuracy: 0.94
# ----------
# Epoch 5/99, current lr=1e-06
# Copied best model weights!
# train loss: 0.014018, dev loss: 0.092045, accuracy: 0.88
# ----------
# Epoch 6/99, current lr=1.0453658778440102e-05
# Copied best model weights!
# train loss: 0.014775, dev loss: 0.090433, accuracy: 0.88
# ----------
# Epoch 7/99, current lr=3.520365877844011e-05
# Copied best model weights!
# train loss: 0.014272, dev loss: 0.087363, accuracy: 1.00
# ----------
# Epoch 8/99, current lr=6.579634122155992e-05
# Copied best model weights!
# train loss: 0.014846, dev loss: 0.082850, accuracy: 1.12
# ----------
# Epoch 9/99, current lr=9.054634122155994e-05
# Copied best model weights!
# train loss: 0.014923, dev loss: 0.077414, accuracy: 1.12
# ----------
# Epoch 10/99, current lr=0.00010000000000000005
# Copied best model weights!
# train loss: 0.013696, dev loss: 0.072412, accuracy: 1.38
# ----------
# Epoch 11/99, current lr=9.054634122155997e-05
# Copied best model weights!
# train loss: 0.013406, dev loss: 0.068358, accuracy: 1.69
# ----------
# Epoch 12/99, current lr=6.579634122155994e-05
# Copied best model weights!
# train loss: 0.012023, dev loss: 0.065868, accuracy: 1.69
# ----------
# Epoch 13/99, current lr=3.520365877844013e-05
# Copied best model weights!
# train loss: 0.010617, dev loss: 0.064567, accuracy: 1.75
# ----------
# Epoch 14/99, current lr=1.0453658778440117e-05
# Copied best model weights!
# train loss: 0.012070, dev loss: 0.064265, accuracy: 1.81
# ----------
# Epoch 15/99, current lr=1e-06
# Copied best model weights!
# train loss: 0.011417, dev loss: 0.064076, accuracy: 1.75
# ----------
# Epoch 16/99, current lr=1.0453658778440102e-05
# Copied best model weights!
# train loss: 0.011544, dev loss: 0.063464, accuracy: 1.81
# ----------
# Epoch 17/99, current lr=3.520365877844012e-05
# Copied best model weights!
# train loss: 0.010204, dev loss: 0.062484, accuracy: 1.94
# ----------
# Epoch 18/99, current lr=6.579634122155995e-05
# Copied best model weights!
# train loss: 0.011043, dev loss: 0.060724, accuracy: 1.94
# ----------
# Epoch 19/99, current lr=9.054634122155998e-05
# Copied best model weights!
# train loss: 0.010169, dev loss: 0.058158, accuracy: 2.12
# ----------
# Epoch 20/99, current lr=0.00010000000000000013
# Copied best model weights!
# train loss: 0.011286, dev loss: 0.056103, accuracy: 2.25
# ----------
# Epoch 21/99, current lr=9.054634122156002e-05
# Copied best model weights!
# train loss: 0.010015, dev loss: 0.054392, accuracy: 2.38
# ----------
# Epoch 22/99, current lr=6.57963412215601e-05
# Copied best model weights!
# train loss: 0.010273, dev loss: 0.052833, accuracy: 2.44
# ----------
# Epoch 23/99, current lr=3.520365877844017e-05
# Copied best model weights!
# train loss: 0.009781, dev loss: 0.051837, accuracy: 2.44
# ----------
# Epoch 24/99, current lr=1.0453658778440132e-05
# Copied best model weights!
# train loss: 0.008761, dev loss: 0.051796, accuracy: 2.50
# ----------
# Epoch 25/99, current lr=1e-06
# train loss: 0.011180, dev loss: 0.051948, accuracy: 2.56
# ----------
# Epoch 26/99, current lr=1.0453658778440102e-05
# Copied best model weights!
# train loss: 0.009645, dev loss: 0.051654, accuracy: 2.56
# ----------
# Epoch 27/99, current lr=3.5203658778440126e-05
# Copied best model weights!
# train loss: 0.010066, dev loss: 0.050773, accuracy: 2.56
# ----------
# Epoch 28/99, current lr=6.579634122155998e-05
# Copied best model weights!
# train loss: 0.008947, dev loss: 0.049351, accuracy: 2.50
# ----------
# Epoch 29/99, current lr=9.054634122156004e-05
# Copied best model weights!
# train loss: 0.009290, dev loss: 0.047251, accuracy: 2.56
# ----------
# Epoch 30/99, current lr=0.00010000000000000018
# Copied best model weights!
# train loss: 0.007408, dev loss: 0.045561, accuracy: 2.62
# ----------
# Epoch 31/99, current lr=9.054634122156008e-05
# Copied best model weights!
# train loss: 0.009178, dev loss: 0.043734, accuracy: 2.56
# ----------
# Epoch 32/99, current lr=6.579634122156005e-05
# Copied best model weights!
# train loss: 0.010014, dev loss: 0.042612, accuracy: 2.75
# ----------
# Epoch 33/99, current lr=3.52036587784402e-05
# Copied best model weights!
# train loss: 0.009807, dev loss: 0.041957, accuracy: 2.81
# ----------
# Epoch 34/99, current lr=1.0453658778440148e-05
# Copied best model weights!
# train loss: 0.006872, dev loss: 0.041872, accuracy: 2.81
# ----------
# Epoch 35/99, current lr=1e-06
# train loss: 0.006961, dev loss: 0.042235, accuracy: 2.81
# ----------
# Epoch 36/99, current lr=1.0453658778440102e-05
# train loss: 0.007963, dev loss: 0.042331, accuracy: 2.81
# ----------
# Epoch 37/99, current lr=3.520365877844013e-05
# train loss: 0.009632, dev loss: 0.041900, accuracy: 2.81
# ----------
# Epoch 38/99, current lr=6.579634122155999e-05
# Copied best model weights!
# train loss: 0.008355, dev loss: 0.040820, accuracy: 2.94
# ----------
# Epoch 39/99, current lr=9.054634122156006e-05
# Copied best model weights!
# train loss: 0.008173, dev loss: 0.039126, accuracy: 2.88
# ----------
# Epoch 40/99, current lr=0.00010000000000000022
# Copied best model weights!
# train loss: 0.007378, dev loss: 0.037768, accuracy: 2.88
# ----------
# Epoch 41/99, current lr=9.054634122156023e-05
# Copied best model weights!
# train loss: 0.008131, dev loss: 0.036629, accuracy: 2.81
# ----------
# Epoch 42/99, current lr=6.579634122156009e-05
# Copied best model weights!
# train loss: 0.006548, dev loss: 0.035789, accuracy: 2.81
# ----------
# Epoch 43/99, current lr=3.520365877844023e-05
# Copied best model weights!
# train loss: 0.005412, dev loss: 0.035615, accuracy: 2.88
# ----------
# Epoch 44/99, current lr=1.045365877844026e-05
# Copied best model weights!
# train loss: 0.007455, dev loss: 0.035508, accuracy: 2.88
# ----------
# Epoch 45/99, current lr=1e-06
# Copied best model weights!
# train loss: 0.006523, dev loss: 0.035379, accuracy: 2.88
# ----------
# Epoch 46/99, current lr=1.0453658778440102e-05
# Copied best model weights!
# train loss: 0.008543, dev loss: 0.035314, accuracy: 2.88
# ----------
# Epoch 47/99, current lr=3.5203658778440336e-05
# train loss: 0.007188, dev loss: 0.035331, accuracy: 2.88
# ----------
# Epoch 48/99, current lr=6.579634122156007e-05
# Copied best model weights!
# train loss: 0.007186, dev loss: 0.034896, accuracy: 2.88
# ----------
# Epoch 49/99, current lr=9.054634122156008e-05
# Copied best model weights!
# train loss: 0.006292, dev loss: 0.034043, accuracy: 2.94
# ----------
# Epoch 50/99, current lr=0.00010000000000000036
# Copied best model weights!
# train loss: 0.007284, dev loss: 0.033000, accuracy: 2.94
# ----------
# Epoch 51/99, current lr=9.054634122156035e-05
# Copied best model weights!
# train loss: 0.005997, dev loss: 0.032319, accuracy: 3.00
# ----------
# Epoch 52/99, current lr=6.579634122156018e-05
# Copied best model weights!
# train loss: 0.006598, dev loss: 0.031917, accuracy: 3.06
# ----------
# Epoch 53/99, current lr=3.520365877844011e-05
# Copied best model weights!
# train loss: 0.005910, dev loss: 0.031579, accuracy: 3.06
# ----------
# Epoch 54/99, current lr=1.0453658778440173e-05
# train loss: 0.005628, dev loss: 0.031829, accuracy: 3.00
# ----------
# Epoch 55/99, current lr=1e-06
# train loss: 0.006805, dev loss: 0.032238, accuracy: 3.00
# ----------
# Epoch 56/99, current lr=1.0453658778440102e-05
# train loss: 0.007565, dev loss: 0.032093, accuracy: 3.06
# ----------
# Epoch 57/99, current lr=3.520365877844001e-05
# Copied best model weights!
# train loss: 0.006649, dev loss: 0.031562, accuracy: 3.00
# ----------
# Epoch 58/99, current lr=6.57963412215601e-05
# Copied best model weights!
# train loss: 0.005965, dev loss: 0.031124, accuracy: 3.06
# ----------
# Epoch 59/99, current lr=9.054634122156012e-05
# Copied best model weights!
# train loss: 0.005397, dev loss: 0.030449, accuracy: 3.12
# ----------
# Epoch 60/99, current lr=0.00010000000000000041
# Copied best model weights!
# train loss: 0.006208, dev loss: 0.029922, accuracy: 3.12
# ----------
# Epoch 61/99, current lr=9.05463412215602e-05
# Copied best model weights!
# train loss: 0.005369, dev loss: 0.029399, accuracy: 3.12
# ----------
# Epoch 62/99, current lr=6.579634122156024e-05
# Copied best model weights!
# train loss: 0.005466, dev loss: 0.029186, accuracy: 3.12
# ----------
# Epoch 63/99, current lr=3.520365877844015e-05
# Copied best model weights!
# train loss: 0.006274, dev loss: 0.028806, accuracy: 3.06
# ----------
# Epoch 64/99, current lr=1.0453658778440193e-05
# train loss: 0.004877, dev loss: 0.029053, accuracy: 3.19
# ----------
# Epoch 65/99, current lr=1e-06
# train loss: 0.007522, dev loss: 0.029170, accuracy: 3.19
# ----------
# Epoch 66/99, current lr=1.0453658778440102e-05
# train loss: 0.007015, dev loss: 0.028935, accuracy: 3.19
# ----------
# Epoch 67/99, current lr=3.520365877844002e-05
# Copied best model weights!
# train loss: 0.003872, dev loss: 0.028780, accuracy: 3.19
# ----------
# Epoch 68/99, current lr=6.579634122156013e-05
# Copied best model weights!
# train loss: 0.005648, dev loss: 0.028425, accuracy: 3.12
# ----------
# Epoch 69/99, current lr=9.054634122156038e-05
# Copied best model weights!
# train loss: 0.005551, dev loss: 0.027719, accuracy: 3.19
# ----------
# Epoch 70/99, current lr=0.00010000000000000047
# Copied best model weights!
# train loss: 0.006908, dev loss: 0.026912, accuracy: 3.19
# ----------
# Epoch 71/99, current lr=9.054634122156027e-05
# Copied best model weights!
# train loss: 0.006322, dev loss: 0.026088, accuracy: 3.19
# ----------
# Epoch 72/99, current lr=6.579634122156029e-05
# Copied best model weights!
# train loss: 0.006111, dev loss: 0.025495, accuracy: 3.31
# ----------
# Epoch 73/99, current lr=3.520365877844051e-05
# Copied best model weights!
# train loss: 0.005988, dev loss: 0.025149, accuracy: 3.25
# ----------
# Epoch 74/99, current lr=1.0453658778440202e-05
# train loss: 0.005154, dev loss: 0.025234, accuracy: 3.25
# ----------
# Epoch 75/99, current lr=1e-06
# Copied best model weights!
# train loss: 0.006329, dev loss: 0.025106, accuracy: 3.25
# ----------
# Epoch 76/99, current lr=1.0453658778440102e-05
# Copied best model weights!
# train loss: 0.005973, dev loss: 0.024677, accuracy: 3.25
# ----------
# Epoch 77/99, current lr=3.520365877844037e-05
# Copied best model weights!
# train loss: 0.006212, dev loss: 0.024539, accuracy: 3.25
# ----------
# Epoch 78/99, current lr=6.579634122156017e-05
# Copied best model weights!
# train loss: 0.004579, dev loss: 0.024330, accuracy: 3.25
# ----------
# Epoch 79/99, current lr=9.054634122156044e-05
# Copied best model weights!
# train loss: 0.005183, dev loss: 0.024272, accuracy: 3.25
# ----------
# Epoch 80/99, current lr=0.00010000000000000056
# Copied best model weights!
# train loss: 0.003878, dev loss: 0.023713, accuracy: 3.25
# ----------
# Epoch 81/99, current lr=9.054634122156057e-05
# Copied best model weights!
# train loss: 0.006123, dev loss: 0.023197, accuracy: 3.25
# ----------
# Epoch 82/99, current lr=6.57963412215607e-05
# train loss: 0.003330, dev loss: 0.023378, accuracy: 3.25
# ----------
# Epoch 83/99, current lr=3.520365877844022e-05
# train loss: 0.005478, dev loss: 0.023304, accuracy: 3.25
# ----------
# Epoch 84/99, current lr=1.0453658778440215e-05
# train loss: 0.003767, dev loss: 0.023493, accuracy: 3.25
# ----------
# Epoch 85/99, current lr=1e-06
# train loss: 0.005720, dev loss: 0.023587, accuracy: 3.19
# ----------
# Epoch 86/99, current lr=1.0453658778440102e-05
# train loss: 0.003851, dev loss: 0.023694, accuracy: 3.19
# ----------
# Epoch 87/99, current lr=3.520365877844005e-05
# train loss: 0.005618, dev loss: 0.023557, accuracy: 3.25
# ----------
# Epoch 88/99, current lr=6.579634122155987e-05
# Copied best model weights!
# train loss: 0.006473, dev loss: 0.022926, accuracy: 3.25
# ----------
# Epoch 89/99, current lr=9.05463412215605e-05
# Copied best model weights!
# train loss: 0.004786, dev loss: 0.022551, accuracy: 3.25
# ----------
# Epoch 90/99, current lr=0.00010000000000000061
# Copied best model weights!
# train loss: 0.007083, dev loss: 0.021894, accuracy: 3.31
# ----------
# Epoch 91/99, current lr=9.054634122156062e-05
# Copied best model weights!
# train loss: 0.004561, dev loss: 0.021601, accuracy: 3.38
# ----------
# Epoch 92/99, current lr=6.579634122156041e-05
# Copied best model weights!
# train loss: 0.005238, dev loss: 0.021503, accuracy: 3.31
# ----------
# Epoch 93/99, current lr=3.520365877844059e-05
# Copied best model weights!
# train loss: 0.005503, dev loss: 0.021470, accuracy: 3.38
# ----------
# Epoch 94/99, current lr=1.0453658778440024e-05
# Copied best model weights!
# train loss: 0.004962, dev loss: 0.021385, accuracy: 3.38
# ----------
# Epoch 95/99, current lr=1e-06
# Copied best model weights!
# train loss: 0.004985, dev loss: 0.021144, accuracy: 3.31
# ----------
# Epoch 96/99, current lr=1.0453658778440102e-05
# Copied best model weights!
# train loss: 0.004785, dev loss: 0.020888, accuracy: 3.31
# ----------
# Epoch 97/99, current lr=3.5203658778440065e-05
# train loss: 0.004036, dev loss: 0.020947, accuracy: 3.31
# ----------
# Epoch 98/99, current lr=6.57963412215599e-05
# Copied best model weights!
# train loss: 0.006511, dev loss: 0.020804, accuracy: 3.31
# ----------
# Epoch 99/99, current lr=9.054634122156055e-05
# Copied best model weights!
# train loss: 0.004433, dev loss: 0.020311, accuracy: 3.38
# ----------

# %%
# Train-Validation Progress
num_epochs=params_train["num_epochs"]

# plot loss progress
plt.title("Train-Val Loss")
plt.plot(range(1,num_epochs+1),loss_hist["train"],label="train")
plt.plot(range(1,num_epochs+1),loss_hist["val"],label="val")
plt.ylabel("Loss")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# plot accuracy progress
plt.title("Train-Val Accuracy")
plt.plot(range(1,num_epochs+1),metric_hist["train"],label="train")
plt.plot(range(1,num_epochs+1),metric_hist["val"],label="val")
plt.ylabel("Accuracy")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# %%
from torch import nn
from torchvision import models

model_resnet18 = models.resnet18(pretrained=False)
num_ftrs = model_resnet18.fc.in_features
num_classes=10
model_resnet18.fc = nn.Linear(num_ftrs, num_classes)

# %%
import torch

path2weights="./models/resnet18_pretrained.pt"
model_resnet18.load_state_dict(torch.load(path2weights))
# Out:
# <All keys matched successfully>

# %%
model_resnet18.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
    model_resnet18=model_resnet18.to(device)

# %%
def deploy_model(model,dataset,device, num_classes=10,sanity_check=False):

    len_data=len(dataset)
    
    # initialize output tensor on CPU: due to GPU memory limits
    y_out=torch.zeros(len_data,num_classes)
    
    # initialize ground truth on CPU: due to GPU memory limits
    y_gt=np.zeros((len_data),dtype="uint8")
    
    # move model to device
    model=model.to(device)
    
    elapsed_times=[]
    with torch.no_grad():
        for i in range(len_data):
            x,y=dataset[i]
            y_gt[i]=y
            start=time.time()    
            yy=model(x.unsqueeze(0).to(device))
            y_out[i]=torch.softmax(yy,dim=1)
            elapsed=time.time()-start
            elapsed_times.append(elapsed)

            if sanity_check is True:
                break

    inference_time=np.mean(elapsed_times)*1000
    print("average inference time per image on %s: %.2f ms " %(device,inference_time))
    return y_out.numpy(),y_gt

# %%
from torchvision import datasets
import torchvision.transforms as transforms

# define transformation
data_transformer = transforms.Compose([transforms.ToTensor()])

path2data="./data"

# loading data
test0_ds=datasets.STL10(path2data, split='test', download=True,transform=data_transformer)
print(test0_ds.data.shape)
# Out:
# Files already downloaded and verified
# (8000, 3, 96, 96)

# %%
from sklearn.model_selection import StratifiedShuffleSplit

sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=0)

indices=list(range(len(test0_ds)))
y_test0=[y for _,y in test0_ds]
for test_index, val_index in sss.split(indices, y_test0):
    print("test:", test_index, "val:", val_index)
    print(len(val_index),len(test_index))
# Out:
# test: [2096 4321 2767 ... 3206 3910 2902] val: [6332 6852 1532 ... 5766 4469 1011]
# 1600 6400

# %%
from torch.utils.data import Subset

val_ds=Subset(test0_ds,val_index)
test_ds=Subset(test0_ds,test_index)

# %%
mean=[0.4467106, 0.43980986, 0.40664646]
std=[0.22414584,0.22148906,0.22389975]

# %%
test0_transformer = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
    ])

# %%
test0_ds.transform=test0_transformer

# %%
import time
import numpy as np

# deploy model 
y_out,y_gt=deploy_model(model_resnet18,val_ds,device=device,sanity_check=False)
print(y_out.shape,y_gt.shape)
# Out:
# average inference time per image on cuda: 7.93 ms
# (1600, 10) (1600,)

# %%
from sklearn.metrics import accuracy_score

# get predictions
y_pred = np.argmax(y_out,axis=1)
print(y_pred.shape,y_gt.shape)

# compute accuracy 
acc=accuracy_score(y_pred,y_gt)
print("accuracy: %.2f" %acc)
# Out:
# (1600,) (1600,)
# accuracy: 0.79

# %%
y_out,y_gt=deploy_model(model_resnet18,test_ds,device=device)

y_pred = np.argmax(y_out,axis=1)
acc=accuracy_score(y_pred,y_gt)
print(acc)
# Out:
# average inference time per image on cuda: 7.95 ms
# 0.80046875

# %%
from torchvision import utils
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
np.random.seed(1)

def imshow(inp, title=None):
    mean=[0.4467106, 0.43980986, 0.40664646]
    std=[0.22414584,0.22148906,0.22389975]
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array(mean)
    std = np.array(std)
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated  

grid_size=4
rnd_inds=np.random.randint(0,len(test_ds),grid_size)
print("image indices:",rnd_inds)

x_grid_test=[test_ds[i][0] for i in rnd_inds]
y_grid_test=[(y_pred[i],y_gt[i]) for i in rnd_inds]

x_grid_test=utils.make_grid(x_grid_test, nrow=4, padding=2)
print(x_grid_test.shape)

plt.rcParams['figure.figsize'] = (10, 5)
imshow(x_grid_test,y_grid_test)
# Out:
# image indices: [5157  235 3980 5192]
# torch.Size([3, 100, 394])

# %%
device_cpu = torch.device("cpu")
y_out,y_gt=deploy_model(model_resnet18,val_ds,device=device_cpu,sanity_check=False)
print(y_out.shape,y_gt.shape)
# Out:
# average inference time per image on cpu: 30.49 ms
# (1600, 10) (1600,)
